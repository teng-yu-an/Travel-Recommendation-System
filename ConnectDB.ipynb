# %% [markdown]
# ### 從MongoDB 撈資料出來 語法

# %% [markdown]
# ##### MongoDB 資料庫架構：
# - **Database:**  travel
#     - **Collention:**  places
#         - **Document1:** {nation: JP ...}
#         - **Document2:** {nation: JP ...}

# %%
# !pip install pymongo

import pymongo
import pandas as pd

# 連線到資料庫
# user: nccustat, password: nccustat
client = pymongo.MongoClient("mongodb+srv://nccustat:nccustat@nccustat.lxkhf1q.mongodb.net/?retryWrites=true&w=majority")
db = client.travel # 選擇操作 travel 資料庫
collection = db.TravelSite # 選擇操作的集合: TravelSite
cursor = collection.find() # 取得資料 # data = collection.find()
Travel_df = pd.DataFrame( list(cursor) )

collection = db.SiteTrend
cursor = collection.find()
Site_df = pd.DataFrame( list(cursor) )

# %%
df_Travel = pd.merge(Travel_df.drop(columns=["_id","lat","lng"]),Site_df.drop(columns="_id"), left_on=["city","county","state","site"], right_on=["city","county","state","site"], how="inner")

# %%
df_Travel.shape
# Out:
# (5461, 16)

# %%
df_Travel.sample(6)
# Out:
#                                                    site            city  \
# 2310                                      Art Works Now   Mount Rainier
# 2254                           Mount Airy Casino Resort          Colwyn
# 1154  State Line Lookout, Palisades Interstate Park ...  Palisades Park
# 2719                                  Park Place Dental    Elmwood Park
# 4333                                       Ocean Bo Inc        El Monte
# 5169                Center for Colorado Women's History          Denver
#
#                county         state  stars  reviews                type  \
# 2310  Prince George's      Maryland    4.7       48   Arts organization
# 2254         Delaware  Pennsylvania    4.0    11083                None
# 1154           Bergen    New Jersey    4.7      777  Tourist attraction
# 2719             Cook      Illinois    4.8      134             Dentist
# 4333      Los Angeles    California    4.3      664  Dim sum restaurant
# ...

# %%
import os

os.chdir('{your direction}')
df_Travel.to_excel('Travel.xlsx',index=False)
